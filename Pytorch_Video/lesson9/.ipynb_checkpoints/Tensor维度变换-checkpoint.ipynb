# %%
import torch
import numpy as np

# %% [markdown]
# ## view / reshape

# %%
a = torch.rand(4, 1, 28, 28)

# %%
a
# Out:
# tensor([[[[0.5538, 0.7822, 0.0877,  ..., 0.1875, 0.3947, 0.9011],
#           [0.4435, 0.3348, 0.6772,  ..., 0.7063, 0.4274, 0.9189],
#           [0.6787, 0.3902, 0.1435,  ..., 0.4471, 0.2078, 0.7372],
#           ...,
#           [0.9739, 0.7790, 0.7430,  ..., 0.7797, 0.2103, 0.8562],
#           [0.5600, 0.3888, 0.9570,  ..., 0.4046, 0.3097, 0.2594],
#           [0.3487, 0.8243, 0.4067,  ..., 0.7741, 0.7598, 0.0453]]],
#
#
#         [[[0.9787, 0.7569, 0.7037,  ..., 0.5920, 0.9148, 0.7100],
#           [0.8845, 0.8294, 0.5969,  ..., 0.2907, 0.5522, 0.0616],
#           [0.7430, 0.9591, 0.0124,  ..., 0.0419, 0.6360, 0.0407],
#           ...,
#           [0.5007, 0.3174, 0.8660,  ..., 0.6643, 0.5344, 0.8881],
#           [0.0644, 0.3416, 0.0665,  ..., 0.2807, 0.2297, 0.2688],
#           [0.4495, 0.6946, 0.9038,  ..., 0.3566, 0.4585, 0.3611]]],
#
#
#         [[[0.4978, 0.4255, 0.3673,  ..., 0.4748, 0.0130, 0.0291],
#           [0.1602, 0.7945, 0.1027,  ..., 0.7832, 0.8009, 0.3194],
# ...

# %%
a.shape
# Out:
# torch.Size([4, 1, 28, 28])

# %%
a.view(4, 28 * 28)
# Out:
# tensor([[0.5538, 0.7822, 0.0877,  ..., 0.7741, 0.7598, 0.0453],
#         [0.9787, 0.7569, 0.7037,  ..., 0.3566, 0.4585, 0.3611],
#         [0.4978, 0.4255, 0.3673,  ..., 0.5476, 0.3802, 0.8663],
#         [0.2603, 0.8039, 0.1333,  ..., 0.8910, 0.0337, 0.3941]])

# %%
a.shape
# Out:
# torch.Size([4, 1, 28, 28])

# %%
a.view(4, 28 * 28).shape
# Out:
# torch.Size([4, 784])

# %%
a.view(4 * 28, 28).shape
# Out:
# torch.Size([112, 28])

# %%
a.view(4 * 1, 28, 28).shape
# Out:
# torch.Size([4, 28, 28])

# %%
b = a.view(4, 784)

# %%
b.view(4, 28, 28, 1)  # logic bug
# Out:
# tensor([[[[0.5538],
#           [0.7822],
#           [0.0877],
#           ...,
#           [0.1875],
#           [0.3947],
#           [0.9011]],
#
#          [[0.4435],
#           [0.3348],
#           [0.6772],
#           ...,
#           [0.7063],
#           [0.4274],
#           [0.9189]],
#
#          [[0.6787],
#           [0.3902],
#           [0.1435],
#           ...,
#           [0.4471],
#           [0.2078],
#           [0.7372]],
#
#          ...,
#
#          [[0.9739],
#           [0.7790],
#           [0.7430],
#           ...,
#           [0.7797],
#           [0.2103],
#           [0.8562]],
#
#          [[0.5600],
#           [0.3888],
#           [0.9570],
#           ...,
#           [0.4046],
#           [0.3097],
#           [0.2594]],
#
#          [[0.3487],
#           [0.8243],
#           [0.4067],
#           ...,
#           [0.7741],
#           [0.7598],
#           [0.0453]]],
#
#
#         [[[0.9787],
#           [0.7569],
#           [0.7037],
# ...

# %% [markdown]
# flexible but prone to corrupt

# %%
a.view(4, 783)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-14-0404691742fb> in <module>()
# ----> 1 a.view(4, 783)
#
# RuntimeError: shape '[4, 783]' is invalid for input of size 3136

# %% [markdown]
# ## squeeze / unsqueeze

# %% [markdown]
# ### unsqueeze  维度增加

# %%
a.shape
# Out:
# torch.Size([4, 1, 28, 28])

# %%
a.unsqueeze(0).shape
# Out:
# torch.Size([1, 4, 1, 28, 28])

# %% [markdown]
# [-5, 5)

# %% [markdown]
# 负数索引是在index之后插入维度

# %%
a.unsqueeze(-1).shape
# Out:
# torch.Size([4, 1, 28, 28, 1])

# %%
a.unsqueeze(4).shape
# Out:
# torch.Size([4, 1, 28, 28, 1])

# %%
a.unsqueeze(-4).shape
# Out:
# torch.Size([4, 1, 1, 28, 28])

# %%
a.unsqueeze(-5).shape
# Out:
# torch.Size([1, 4, 1, 28, 28])

# %%
a.unsqueeze(5).shape
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-b54eab361a50> in <module>()
# ----> 1 a.unsqueeze(5).shape
#
# IndexError: Dimension out of range (expected to be in range of [-5, 4], but got 5)

# %%
a = torch.tensor([1.2, 2.3])

# %%
a.unsqueeze(-1)
# Out:
# tensor([[1.2000],
#         [2.3000]])

# %%
a.unsqueeze(0)
# Out:
# tensor([[1.2000, 2.3000]])

# %%
a.unsqueeze(-2)
# Out:
# tensor([[1.2000, 2.3000]])

# %%
a.unsqueeze(1)
# Out:
# tensor([[1.2000],
#         [2.3000]])

# %%
a.unsqueeze()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-c81ad8e7d4e0> in <module>()
# ----> 1 a.unsqueeze()
#
# TypeError: unsqueeze() missing 1 required positional arguments: "dim"

# %% [markdown]
# For example

# %%
b = torch.rand(32)
f = torch.rand(4, 32, 14, 14)

# %%
b = b.unsqueeze(1).unsqueeze(2).unsqueeze(0)

# %%
b.shape
# Out:
# torch.Size([1, 32, 1, 1])

# %% [markdown]
# ### squeeze  维度删减

# %%
b.shape
# Out:
# torch.Size([1, 32, 1, 1])

# %%
b.squeeze().shape   # 能挤压的就都挤压
# Out:
# torch.Size([32])

# %%
b.squeeze(0).shape
# Out:
# torch.Size([32, 1, 1])

# %%
b.squeeze(-1).shape
# Out:
# torch.Size([1, 32, 1])

# %%
b.squeeze(1).shape
# Out:
# torch.Size([1, 32, 1, 1])

# %%
b.squeeze(-4).shape
# Out:
# torch.Size([32, 1, 1])

# %% [markdown]
# ## expand / repeat

# %% [markdown]
# - expand: broadcasting
# - repeat: memory copied

# %% [markdown]
# expand只在有需要的时候才会复制数据
# 而repeat直接复制数据

# %%
a = torch.rand(4, 32,14,14)

# %%
a
# Out:
# tensor([[[[9.4608e-01, 8.7725e-01, 2.6526e-02,  ..., 6.6633e-01,
#            3.1925e-01, 4.6186e-01],
#           [7.5689e-01, 7.2546e-01, 7.5907e-02,  ..., 2.3477e-01,
#            6.5216e-01, 4.8699e-01],
#           [9.0687e-01, 5.5201e-01, 7.4056e-01,  ..., 7.9742e-01,
#            1.3355e-01, 2.3384e-01],
#           ...,
#           [3.7944e-01, 1.1736e-01, 2.3752e-01,  ..., 6.1592e-01,
#            6.1725e-01, 6.0615e-01],
#           [3.8376e-02, 4.4278e-01, 4.7441e-01,  ..., 6.7434e-01,
#            2.7414e-01, 2.9226e-01],
#           [9.1284e-01, 8.1791e-01, 9.2018e-01,  ..., 2.1504e-01,
#            9.2348e-01, 1.4895e-01]],
#
#          [[6.7663e-01, 6.4343e-01, 9.4760e-02,  ..., 6.4240e-01,
#            8.1661e-01, 9.2896e-01],
#           [3.5139e-01, 4.8185e-02, 9.5281e-01,  ..., 6.9433e-01,
#            4.8981e-01, 9.9099e-01],
#           [3.8872e-01, 8.1773e-01, 9.3959e-02,  ..., 7.1660e-01,
#            2.6315e-01, 1.8904e-01],
#           ...,
# ...

# %%
b.shape
# Out:
# torch.Size([1, 32, 1, 1])

# %%
b.expand(4, 32, 14,14).shape
# Out:
# torch.Size([4, 32, 14, 14])

# %%
b.expand(-1, 32, -1, -1).shape
# Out:
# torch.Size([1, 32, 1, 1])

# %%
b.expand(-1, -1, -1, -4).shape
# Out:
# torch.Size([1, 32, 1, -4])

# %%
b.expand(-1,-1,-1,-4)  # -4为Pytorch的bug
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# D:\Anaconda\envs\Pytorch\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     697                 type_pprinters=self.type_printers,
#     698                 deferred_pprinters=self.deferred_printers)
# --> 699             printer.pretty(obj)
#     700             printer.flush()
#     701             return stream.getvalue()
#
# D:\Anaconda\envs\Pytorch\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     401                         if cls is not object \
#     402                                 and callable(cls.__dict__.get('__repr__')):
# --> 403                             return _repr_pprint(obj, self, cycle)
#     404
#     405             return _default_pprint(obj, self, cycle)
#
# D:\Anaconda\envs\Pytorch\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
# ...

# %%
b.shape
# Out:
# torch.Size([1, 32, 1, 1])

# %%
b.repeat(4, 32, 1, 1).shape   # repeat中的参数是原来每一个维度需要重复的次数
# Out:
# torch.Size([4, 1024, 1, 1])

# %%
b.repeat(4, 1, 1, 1).shape
# Out:
# torch.Size([4, 32, 1, 1])

# %%
b.repeat(4, 1, 32, 32).shape
# Out:
# torch.Size([4, 32, 32, 32])

# %% [markdown]
# ## .t

# %%
b.t()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-57-b510e0f64f40> in <module>()
# ----> 1 b.t()
#
# RuntimeError: t() expects a tensor with <= 2 dimensions, but self is 4D

# %%
a = torch.randn(3, 4)
a
# Out:
# tensor([[ 0.3822, -2.3293, -0.7606,  0.7282],
#         [-1.3862, -1.2782, -0.2236,  0.2936],
#         [ 0.0044,  2.3088,  0.3881, -1.2862]])

# %%
a.t()
# Out:
# tensor([[ 0.3822, -1.3862,  0.0044],
#         [-2.3293, -1.2782,  2.3088],
#         [-0.7606, -0.2236,  0.3881],
#         [ 0.7282,  0.2936, -1.2862]])

# %% [markdown]
# ## transpose

# %%
a = torch.randn(4, 3, 32, 32)

# %%
a.shape
# Out:
# torch.Size([4, 3, 32, 32])

# %%
a1 = a.transpose(1, 3).view(4, 3 * 32 * 32).view(4, 3, 32, 32)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-63-0b5ac7f4d497> in <module>()
# ----> 1 a1 = a.transpose(1, 3).view(4, 3 * 32 * 32).view(4, 3, 32, 32)
#
# RuntimeError: view size is not compatible with input tensor's size and stride (at least one dimension spans across two contiguous subspaces). Use .reshape(...) instead.

# %%
# a1造成数据污染
# contiguous重新分配内存，使得矩阵在内存中连续
a1 = a.transpose(1, 3).contiguous().view(4, 3 * 32 * 32).view(4, 3, 32, 32)

# %%
a2 = a.transpose(1, 3).contiguous().view(4, 3 * 32 * 32).view(4, 32, 32, 3).transpose(1, 3)

# %%
torch.all(torch.eq(a, a1))
# Out:
# tensor(False)

# %%
torch.all(torch.eq(a, a2))
# Out:
# tensor(True)

# %% [markdown]
# ## permute

# %%
a = torch.rand(4, 3, 28, 28)

# %%
a.transpose(1, 3).shape
# Out:
# torch.Size([4, 28, 28, 3])

# %%
b = torch.randn(4, 3, 28, 32)

# %%
b.transpose(1, 3).shape
# Out:
# torch.Size([4, 32, 28, 3])

# %%
b.transpose(1, 3).transpose(1, 2).shape
# Out:
# torch.Size([4, 28, 32, 3])

# %%
b.permute(0, 2, 3, 1).shape
# Out:
# torch.Size([4, 28, 32, 3])
